# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate

# %%
os.environ["GOOGLE_API_KEY"] = "MY GEMINI KEY"

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# %%
prompt = PromptTemplate.from_template("""
Movie: {movie_name}

1. What year was this movie released?
2. From 2026, how many years ago was that?

Return in format:
Movie: {movie_name}
Released Year: XXXX
Years Ago: XXXX
""")

# %%
chain = prompt | llm

# %%
movie = input("Enter a movie name: ")
response = chain.invoke({"movie_name": movie})
print(response.content)
# Out:
# Movie: Interstellar
# Released Year: 2014
# Years Ago: 12
